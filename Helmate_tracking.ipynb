# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.0 MB/s eta 0:00:00
# ...

# %%
# !unzip Helmate.v1i.yolov8.zip
# Out:
# Archive:  Helmate.v1i.yolov8.zip
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data='/content/data.yaml',epochs=100)
# Out:
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1882.1±828.3 MB/s, size: 53.0 KB)
# val: Scanning /content/valid/labels.cache... 126 images, 30 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 126/126 254.4Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.0s
#                    all        126        252      0.757      0.678      0.749      0.304
# Speed: 8.3ms preprocess, 5.8ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to /content/runs/detect/train32

# %%
path = '/content/traffic.webp'
resu = model(path)  # Predict on an image
resu[0].show()
# Out:
# image 1/1 /content/traffic.webp: 448x640 2 helmates, 9.6ms
# Speed: 3.3ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=612x406>
